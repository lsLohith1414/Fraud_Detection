# %% [markdown]
# # 📌 Data Validation — The Correct Next Step After Data Ingestion
#
# ---
#
# ## 1️⃣ What is the NEXT step after Data Ingestion?
#
# ✅ **Data Validation**
#
# ❌ **NOT** Data Transformation.
#
# ### Always follow this order:
#
# **Data Ingestion**
# → **Data Validation**
# → **Data Transformation**
# → **Model Training**
# → **Model Evaluation**
# → **Deployment**
#
# ### Why?
#
# Because you must **verify the data is trustworthy before you transform it.**
#
# ---
#
# ## 2️⃣ What is Data Validation? (REAL meaning)
#
# **Data Validation** =
# > “Can this data be used safely for training?”
#
# It is a **quality gate**.
#
# Think of it as **unit testing for data**.
#
# ---
#
# ## 3️⃣ What Data Validation is NOT (Very Important)
#
# ❌ **Data Validation is NOT:**
#
# - scaling
# - encoding
# - imputation
# - feature engineering
# - SMOTE
# - normalization
#
# 👉 These belong to **Data Transformation**.
#
# ---
#
# ## 4️⃣ What exactly do we do in Data Validation?
#
# > **Industry-standard data validation includes ONLY checks, not fixes.**
#
# ---
#
# ### 🔹 1️⃣ Schema Validation
#
# Check:
# - column names
# - data types
# - required columns exist
#
# **Example schema:**
#
# - TransactionID: `int`
# - Amount: `float`
# - FraudIndicator: `int`
#
# ❌ If mismatch → **FAIL**
#
# ---
#
# ### 🔹 2️⃣ Train/Test Structure Validation
#
# Ensure:
# - train and test have same columns
# - target column exists
# - no missing target column
#
# ---
#
# ### 🔹 3️⃣ Null Value Checks (Detection only)
#
# Check:
# - percentage of missing values
# - columns exceeding threshold
#
# **Example:**
#
# - Amount missing > 30% → **FAIL**
#
# ❌ **Do NOT fill missing values here.**
#
# ---
#
# ### 🔹 4️⃣ Duplicate Record Detection
#
# Check:
# - duplicate rows
# - duplicate primary keys
#
# **Example:**
#
# - TransactionID duplicated → **FAIL**
#
# ---
#
# ### 🔹 5️⃣ Data Drift Detection (VERY IMPORTANT)
#
# Compare:
# - current train data
# - previous train data (from last run)
#
# Check:
# - distribution changes
# - KS-test / PSI
#
# If drift > threshold → **WARN / FAIL**
#
# ---
#
# ### 🔹 6️⃣ Basic Range & Sanity Checks
#
# **Examples:**
#
# - Amount < 0 → invalid
# - Age < 0 or > 120 → invalid
#
# ---
#
# ### 🔹 7️⃣ Save Validation Artifacts
#
# - validation report (JSON / HTML)
# - valid / invalid datasets
# - drift report
#
# ---
#
# ## 5️⃣ What Data Validation OUTPUTS
#
# ❌ It does **NOT** modify data.
#
# ✅ It outputs:
#
# ```python
# DataValidationArtifact(
#     validation_status=True,
#     valid_train_file_path="...",
#     valid_test_file_path="...",
#     drift_report_file_path="..."
# )
# ```
#
#
# ## 6️⃣ Example with YOUR Fraud Dataset
#
# **Data Validation will check:**
#
# ✔ Columns exist:
#
# - TransactionID
# - CustomerID
# - MerchantID
# - FraudIndicator
#
# ✔ Types:
#
# - TransactionID → int
# - Amount → float
# - FraudIndicator → int
#
# ✔ No negative transaction amounts
#
# ✔ Target column exists
#
# ✔ No schema mismatch between train & test
#
# ✔ Distribution shift in:
#
# - Amount
# - AnomalyScore
#
# ---
#
# ## 7️⃣ What happens if validation FAILS?
#
# **Industry behavior:**
#
# ❌ Stop pipeline
#
# ❌ Do NOT train model
#
# ✔ Log error
#
# ✔ Raise exception
#
# ✔ Alert (in real systems)
#
# ---
#
# ## 8️⃣ Final Pipeline Order (LOCK THIS)
#
# 1. Data Ingestion
# 2. **Data Validation ← YOU ARE HERE**
# 3. Data Transformation
# 4. Model Training
# 5. Model Evaluation
# 6. Model Registry
# 7. Deployment
#
# ---
#
# ## 🧠 One-line memory (IMPORTANT)
#
# **Validation checks correctness**
# **Transformation changes data**
#
# ---
#
# ## 🎯 Interview-ready answer
#
# > “After data ingestion, we perform data validation to verify schema integrity, detect missing values, duplicates, and data drift before applying any transformations.”
#
# This answer is **excellent**.
#
# ---
#
# ## ✅ Final confirmation
#
# - **Next step** → Data Validation
# - **Purpose** → Trust the data
# - **No preprocessing here**
# - **Only checks & reports**

# %% [markdown]
# # 📊 Data Drift — Deep Understanding (From Intuition to Practice)
#
# ---
#
# ## 1️⃣ What is Data Drift? (INTUITION FIRST)
#
# **Simple definition:**
#
# **Data Drift** = the data you trained on is no longer similar to the data you are using now.
#
# That’s it.
#
# ---
#
# ### Real-life analogy
#
# Imagine:
#
# - You studied for an exam using last year’s question pattern
# - This year, the pattern changes
# - You still use old preparation → performance drops
#
# That change in pattern = **drift**
#
# ---
#
# ### In ML terms
#
# - **Training data**: what the model learned from
# - **New data**: what the model sees later (test / production)
#
# If their **distributions change**, the model becomes **unreliable**.
#
# ---
#
# ## 2️⃣ Why Data Drift Detection is VERY IMPORTANT (REAL WORLD)
#
# **Key truth (memorize this):**
#
# > **Models don’t fail suddenly — data changes first.**
#
# ---
#
# ### What happens WITHOUT drift detection?
#
# - Model accuracy silently drops
# - Fraud model starts missing frauds
# - Business loses money
# - No obvious error is thrown
#
# ⚠️ **This is the most dangerous failure in ML.**
#
# ---
#
# ### What drift detection gives you
#
# ✔ Early warning
# ✔ Decide when to retrain
# ✔ Prevent silent failures
# ✔ Protect business decisions
#
# This is why **every serious MLOps system monitors drift.**
#
# ---
#
# ## 3️⃣ Types of Drift (VERY IMPORTANT)
#
# There are **3 types**, but you will mostly implement **2**.
#
# ---
#
# ### 🔹 1️⃣ Data Drift (Feature Drift) ← YOU ARE IMPLEMENTING
#
# Feature distributions change.
#
# **Example:**
#
# - Transaction Amounts used to be mostly ₹500–₹2,000
# - Now most transactions are ₹50,000+
#
# Model never saw this → **confused**
#
# ---
#
# ### 🔹 2️⃣ Concept Drift (Harder)
#
# Relationship between features and target changes.
#
# **Example:**
#
# - Earlier, high amount = fraud
# - Now fraudsters do small frequent transactions
#
# Harder to detect automatically.
#
# ---
#
# ### 🔹 3️⃣ Label Drift (Rare)
#
# Target distribution changes.
#
# **Example:**
#
# - Fraud rate increases from 2% → 10%
#
# ---
#
# ## 4️⃣ What is KS Test? (Kolmogorov–Smirnov)
#
# **Used for:**
#
# ✅ Numerical features
#
# ---
#
# ### What KS test answers
#
# > “Are these two distributions statistically different?”
#
# It compares:
#
# - Distribution of feature in old data
# - Distribution of same feature in new data
#
# ---
#
# ### Output of KS test
#
# - **p-value** (between 0 and 1)
#
# **Interpretation:**
#
# - p-value small → distributions differ
# - p-value large → distributions similar
#
# **Example:**
#
# - p-value = 0.01 → drift detected
# - p-value = 0.50 → no drift
#
# ---
#
# ### Why KS is popular
#
# ✔ Simple
# ✔ Non-parametric (no assumptions)
# ✔ Fast
# ✔ Widely accepted
#
# That’s why you chose it — **good choice**.
#
# ---
#
# ## 5️⃣ What is PSI? (Population Stability Index)
#
# **Used for:**
#
# ✅ Numerical features
# ✅ Categorical features
#
# Especially popular in **banking & fraud systems**.
#
# ---
#
# ### What PSI answers
#
# > “How much has the population shifted compared to before?”
#
# PSI measures **magnitude of change**, not just “same/different”.
#
# ---
#
# ### PSI interpretation (VERY IMPORTANT)
#
# | PSI value | Meaning |
# |---------|--------|
# | < 0.1 | No drift |
# | 0.1 – 0.25 | Moderate drift |
# | > 0.25 | Significant drift |
#
# This is **industry-standard**.
#
# ---
#
# ### Why banks love PSI
#
# - Easy to explain to auditors
# - Stable
# - Threshold-based
#
# ---
#
# ## 6️⃣ KS vs PSI — When to use which?
#
# | Scenario | Use |
# |-------|-----|
# | Quick statistical test | KS |
# | Business monitoring | PSI |
# | Numerical data | Both |
# | Categorical data | PSI |
# | Regulatory reporting | PSI |
#
# 👉 **In practice:**
#
# - KS → validation gate
# - PSI → monitoring dashboard
#
# ---
#
# ## 7️⃣ How this fits into YOUR fraud project
#
# ### What you are doing (correct)
#
# - Compare train vs test now
# - Later → train vs production
# - Use KS test for numerical features
#
# This is **exactly right** for learning + interviews.
#
# ---
#
# ### Example in your dataset
#
# **Feature:** TransactionAmount
#
# - Train distribution: mostly low values
# - New data: higher amounts
#
# KS detects:
#
# - p-value = 0.02 → drift detected
#
# You:
#
# - log it
# - store JSON report
# - decide whether to retrain
#
# ---
#
# ## 8️⃣ IMPORTANT MISCONCEPTIONS (CLEAR THESE)
#
# ❌ Drift ≠ bad model
# ❌ Drift ≠ error
# ❌ Drift ≠ preprocessing issue
#
# ✅ Drift = **environment change**
#
# ---
#
# ## 9️⃣ One-line memory rules (LOCK THESE)
#
# - **Drift is about data, not models**
# - **KS answers “Are they different?”**
# - **PSI answers “How different?”**
#
# ---
#
# ## 🎯 Interview-ready answer (VERY IMPORTANT)
#
# > “Data drift occurs when feature distributions change over time, causing model performance degradation. We detect drift using statistical tests like KS or PSI to trigger retraining before performance drops.”
#
# This is a **strong professional answer**.
#
# ---
#
# ## ✅ Final confidence check
#
# ✔ You now understand what drift is
# ✔ You know why it matters
# ✔ You know KS vs PSI
# ✔ You know why you’re using KS now
#
# ---
#
# **Next, if you want:**
#
# - Implement KS & PSI cleanly
# - Show how drift gates retraining
# - Move to Data Transformation step

# %% [markdown]
# # 🔑 Drift Detection — Where and Why It Is Used
#
# ---
#
# ## 🔑 SHORT ANSWER (FIRST)
#
# Drift detection is used in **TWO places** for **TWO different reasons**.
#
# ✔ Before training → **Data Validation**
# ✔ After deployment → **Monitoring**
#
# Same concept, **different purpose**.
#
# ---
#
# ## 1️⃣ WHY drift detection is used in Data Validation
#
# **Context here:**
#
# You are in the **training pipeline**, not production.
#
# You have:
#
# - Train data
# - Test / new batch data
#
# **Question Data Validation asks:**
#
# > “Is this new data statistically similar to what I trained on?”
#
# ---
#
# ### If NO:
#
# - Training results will be misleading
# - Evaluation metrics are unreliable
#
# ---
#
# ### Example (very important)
#
# Suppose:
#
# - Train data = transactions from **2022**
# - Test data = transactions from **2025**
#
# If distributions differ:
#
# - Model evaluation is **not trustworthy**
# - High accuracy is **false confidence**
#
# 👉 So drift detection here is a **QUALITY GATE**.
#
# ---
#
# ## 2️⃣ WHY drift detection is used after deployment
#
# **Context:**
#
# Model is live in **production**.
#
# **Question monitoring asks:**
#
# > “Has real-world data changed compared to training data?”
#
# ---
#
# ### If YES:
#
# - Model performance will degrade
# - Retraining is required
#
# 👉 Here drift detection is a **MONITORING SIGNAL**.
#
# ---
#
# ## 3️⃣ SAME TOOL, DIFFERENT INTENT (KEY IDEA)
#
# | Stage | Why drift is checked | Action |
# |------|--------------------|--------|
# | Data Validation | Ensure fair evaluation | Stop / warn pipeline |
# | Production Monitoring | Detect model decay | Retrain / alert |
#
# Same **KS / PSI tests**.
# Different **decisions**.
#
# ---
#
# ## 4️⃣ Visual timeline (VERY IMPORTANT)

# %%
RAW DATA
↓
DATA INGESTION
↓
DATA VALIDATION
├── schema check
├── missing values
├── drift (train vs test) ← QUALITY CHECK
↓
DATA TRANSFORMATION
↓
MODEL TRAINING
↓
MODEL DEPLOYMENT
↓
PRODUCTION MONITORING
├── drift (train vs live) ← MONITORING
├── performance
└── alerts

# %% [markdown]
# ---
#
# ## 5️⃣ Why many people get confused (truth)
#
# **Most tutorials:**
#
# - Skip validation drift
# - Only talk about production drift
#
# **Industry:**
#
# - Does **both**
#
# That’s why your confusion is **normal**.
#
# ---
#
# ## 6️⃣ Real-world analogy (easy to remember)
#
# **Data Validation drift**
#
# > “Are my test questions similar to practice questions?”
#
# **Production drift**
#
# > “Is the real exam still following the same pattern?”
#
# Same idea.
# Different time.
#
# ---
#
# ## 7️⃣ Important distinction (LOCK THIS)
#
# - **Validation drift protects model evaluation**
# - **Monitoring drift protects business**
#
# Both are **critical**.
#
# ---
#
# ## 8️⃣ What happens if you skip validation drift?
#
# - Model looks good in offline tests
# - Fails in real world
# - You don’t know why
#
# This is **very dangerous**.
#
# ---
#
# ## 9️⃣ Industry rule (VERY IMPORTANT)
#
# Every serious ML system checks drift **before training**
# **AND**
# **after deployment**.
#
# ---
#
# ## 🎯 Interview-ready answer (THIS IS GOLD)
#
# > “We perform drift detection both during data validation to ensure reliable model evaluation and post-deployment to monitor real-world data shifts and trigger retraining.”
#
# This answer shows **deep MLOps understanding**.
#
# ---
#
# ## ✅ Final clarity check
#
# ✔ Your original thought was not wrong
# ✔ You were missing the training-stage use
# ✔ Now you know why both exist
# ✔ Your pipeline design is correct

# %% [markdown]
# # 🔒 Locked understanding
#
# ### Data Validation drift
# * → compare train data vs test data
# * → purpose: ensure fair, reliable evaluation
#
# ### Production monitoring drift
# * → compare training data vs live/production data
# * → purpose: detect model decay
#
# ## One-line rule (memorize this)
#
# * Validation drift = train vs test
# * Monitoring drift = train vs production
