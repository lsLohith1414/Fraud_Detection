# %% [markdown]
# # DVC Pipeline

# %% [markdown]
# ## ✅ What happens with your current Python pipeline
#
# When you run:
#
# ```bash
# python training_pipeline.py
# ```
#
# ### Behavior:
#
# ❌ ALL steps run every time
# ❌ Artifacts are recreated every time
#
# ❌ Even if:
# - data didn’t change
# - code didn’t change
# - parameters didn’t change
#
# ### Result:
# - New CSVs
# - New features
# - New models
# - New metrics
#
# ➡️ No memory of previous runs
#
# ---
#
# ## ✅ What happens with a DVC pipeline
#
# When you run:
#
# ```bash
# dvc repro
# ```
#
# ### Behavior:
#
# ✅ DVC checks hashes of:
# - input data
# - code
# - parameters
#
# ✅ If NOTHING changed:
# - ❌ No stages are executed
# - ❌ No new artifacts are created
#
# ✅ DVC reuses cached outputs
#
# ➡️ Artifacts are NOT recreated
#
# ---
#
# ## 🔥 Key distinction (LOCK THIS)
#
# - **Python pipeline = imperative execution**
# - **DVC pipeline = declarative execution**
