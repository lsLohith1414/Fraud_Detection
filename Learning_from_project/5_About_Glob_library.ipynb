# %% [markdown]
# # 1️⃣ What is glob? (VERY SIMPLE)
# * Think of glob as file finder
#
# #### If you do this on your computer:
#
# > * Open a folder
#
# > * Type *.csv
#
# > * It shows all CSV files
#
# > * 👉 glob does exactly that, but in Python.
#
# ### Example (outside your code)
# ``` python
# import glob
#
# glob.glob("data/*.csv")
# ```
#
# ### Means:
#
# * “Give me all files ending with .csv inside the data folder.”

# %%
import glob


print(glob.glob("Fraud_dataset/Data/Customer Profiles/*.csv"))
